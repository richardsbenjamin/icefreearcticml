# %%
import xarray as xr

# %% [markdown]
# ### Precompute

# %%
ice_free_year_ds_path = "/home/benjamin/icefreearcticml/outputs/ice_free_year_ds.nc"
bias_ds_path = "/home/benjamin/icefreearcticml/outputs/bias_ds.nc"

# %%
ice_free_year_ds = xr.open_dataset(ice_free_year_ds_path)
bias_ds = xr.open_dataset(bias_ds_path)
